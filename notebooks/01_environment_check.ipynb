# %% [markdown]
# # Environment Check
#
# This notebook verifies that the Jupyter environment is set up correctly and all required packages are installed.

# %% [markdown]
# ## 1. Python Version

# %%
import sys
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")

# %% [markdown]
# ## 2. Package Imports
#
# Testing that all key data engineering packages can be imported.

# %%
# Core data packages
import pandas as pd
import numpy as np

# Spark
import pyspark
from pyspark.sql import SparkSession

# Arrow for Spark-Pandas optimization
import pyarrow

# Database connectivity
import sqlalchemy

# Data formats
import duckdb

print("All packages imported successfully!")

# %% [markdown]
# ## 3. Package Versions

# %%
packages = {
    "pandas": pd.__version__,
    "numpy": np.__version__,
    "pyspark": pyspark.__version__,
    "pyarrow": pyarrow.__version__,
    "sqlalchemy": sqlalchemy.__version__,
    "duckdb": duckdb.__version__,
}

print("Package Versions:")
print("-" * 30)
for pkg, version in packages.items():
    print(f"{pkg:15} {version}")

# %% [markdown]
# ## 4. Quick Functionality Test

# %%
# Create a simple pandas DataFrame
df = pd.DataFrame({
    "message": ["Hello", "Data", "Engineering!"],
    "value": [1, 2, 3]
})

print("Sample DataFrame:")
display(df)

print(f"\nSum of values: {df['value'].sum()}")
print("\nEnvironment check completed successfully!")
